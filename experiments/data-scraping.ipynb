# %%
import pandas as pd
import numpy as np

# %%
import pandas_ta as ta

# %%
ticker = "AAPL"
period = "max"
interval = "1d"
# df = pd.DataFrame().ta.ticker(ticker, start="2021-01-01", end="2021-01-02", interval=interval)
df = pd.DataFrame().ta.ticker(ticker, period=period, interval=interval)
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.100764    0.101203    0.100764    0.100764
# 1980-12-15 00:00:00-05:00    0.095946    0.095946    0.095508    0.095508
# 1980-12-16 00:00:00-05:00    0.088936    0.088936    0.088498    0.088498
# 1980-12-17 00:00:00-05:00    0.090688    0.091126    0.090688    0.090688
# 1980-12-18 00:00:00-05:00    0.093317    0.093755    0.093317    0.093317
# ...                               ...         ...         ...         ...
# 2023-05-17 00:00:00-04:00  171.710007  172.929993  170.419998  172.690002
# 2023-05-18 00:00:00-04:00  173.000000  175.240005  172.580002  175.050003
# 2023-05-19 00:00:00-04:00  176.389999  176.389999  174.940002  175.160004
# 2023-05-22 00:00:00-04:00  173.979996  174.710007  173.449997  174.199997
# 2023-05-23 00:00:00-04:00  173.130005  173.379395  172.125000  172.169998
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
df.ta.categories
# Out:
# ['candles',
#  'cycles',
#  'momentum',
#  'overlap',
#  'performance',
#  'statistics',
#  'trend',
#  'volatility',
#  'volume']

# %%
result = df.ta.strategy("Momentum")
print(result)
print(type(result))
# Out:
# 39it [00:01, 19.76it/s]
# None
# <class 'NoneType'>

# %%
# Create your own Custom Strategy
CustomStrategy = ta.Strategy(
    name="Momo and Volatility",
    description="SMA 50,200, BBANDS, RSI, MACD and Volume SMA 20",
    ta=[
        {"kind": "sma", "length": 50},
        {"kind": "sma", "length": 200},
        {"kind": "bbands", "length": 20},
        {"kind": "rsi"},
        {"kind": "macd", "fast": 8, "slow": 21},
        {"kind": "sma", "close": "volume", "length": 20, "prefix": "VOLUME"},
    ]
)
# To run your "Custom Strategy"
df.ta.strategy(CustomStrategy)

# %%
df.ta.indicators()
# Out:
# Pandas TA - Technical Analysis Indicators - v0.3.14b0
# Total Indicators & Utilities: 205
# Abbreviations:
# ...

# %%
df2 = df.ta.ticker("aapl", period="1y", interval="1h")

# %%
df.ta.strategy(ta.AllStrategy)
# Out:
# 0it [00:00, ?it/s]/opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/pool.py:48: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   return list(map(*args))
# /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/pool.py:48: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   return list(map(*args))
# /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/pool.py:48: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return list(map(*args))
# 131it [00:01, 89.50it/s]

# %%
for i in df.columns:
    print(i)
# Out:
# Open
# High
# Low
# Close
# Volume
# Dividends
# Stock Splits
# AO_5_34
# APO_12_26
# BIAS_SMA_26
# BOP
# AR_26
# BR_26
# CCI_14_0.015
# CFO_9
# CG_10
# CMO_14
# COPC_11_14_10
# CTI_12
# ER_10
# BULLP_13
# BEARP_13
# FISHERT_9_1
# FISHERTs_9_1
# INERTIA_20_14
# K_9_3
# D_9_3
# J_9_3
# KST_10_15_20_30_10_10_10_15
# KSTs_9
# MACD_12_26_9
# MACDh_12_26_9
# MACDs_12_26_9
# MOM_10
# PGO_14
# PPO_12_26_9
# PPOh_12_26_9
# PPOs_12_26_9
# PSL_12
# PVO_12_26_9
# PVOh_12_26_9
# PVOs_12_26_9
# QQE_14_5_4.236
# QQE_14_5_4.236_RSIMA
# QQEl_14_5_4.236
# QQEs_14_5_4.236
# ROC_10
# RSI_14
# RSX_14
# RVGI_14_4
# RVGIs_14_4
# SLOPE_1
# SMI_5_20_5
# SMIs_5_20_5
# SMIo_5_20_5
# SQZ_20_2.0_20_1.5
# SQZ_ON
# SQZ_OFF
# SQZ_NO
# SQZPRO_20_2.0_20_2_1.5_1
# SQZPRO_ON_WIDE
# SQZPRO_ON_NORMAL
# SQZPRO_ON_NARROW
# SQZPRO_OFF
# SQZPRO_NO
# STC_10_12_26_0.5
# STCmacd_10_12_26_0.5
# STCstoch_10_12_26_0.5
# STOCHk_14_3_3
# STOCHd_14_3_3
# STOCHRSIk_14_14_3_3
# STOCHRSId_14_14_3_3
# TRIX_30_9
# TRIXs_30_9
# ...

# %%
t = yf.Tickers("aapl pltr")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 t = yf.Tickers("aapl pltr")
#
# NameError: name 'yf' is not defined

# %%
import requests_cache
session = requests_cache.CachedSession('yfinance.cache')
session.headers['User-agent'] = 'my-program/1.0'
ticker = yf.Ticker('msft', session=session)
# The scraped response will be stored in the cache
ticker.history(period="1d", interval="1m")
# Out:
#                                  Open        High         Low       Close
# Datetime
# 2023-05-22 09:30:00-04:00  318.600006  318.690002  318.010010  318.230011  \
# 2023-05-22 09:31:00-04:00  318.230011  318.739990  318.220001  318.570007
# 2023-05-22 09:32:00-04:00  318.554993  319.100006  318.510010  318.549988
# 2023-05-22 09:33:00-04:00  318.549988  319.140015  318.399994  319.029999
# 2023-05-22 09:34:00-04:00  319.059998  319.790009  319.059998  319.769989
# ...                               ...         ...         ...         ...
# 2023-05-22 15:55:00-04:00  320.809998  320.890015  320.700012  320.839996
# 2023-05-22 15:56:00-04:00  320.859985  321.010010  320.799988  320.989990
# 2023-05-22 15:57:00-04:00  320.984985  321.109985  320.940002  321.079987
# 2023-05-22 15:58:00-04:00  321.079987  321.230011  321.059998  321.166809
# 2023-05-22 15:59:00-04:00  321.165009  321.290009  321.049988  321.234985
#
#                             Volume  Dividends  Stock Splits
# ...

# %%
import pandas as pd
import pandas_ta as ta

pd.DataFrame().ta.ticker("BRK-A")
# Out:
#                                Open      High           Low     Close  Volume  \
# Date
# 1980-03-17 00:00:00-05:00     290.0     310.0     290.00000     290.0   10000
# 1980-03-18 00:00:00-05:00     290.0     290.0     290.00000     290.0       0
# 1980-03-19 00:00:00-05:00     290.0     310.0     290.00000     290.0   20000
# 1980-03-20 00:00:00-05:00     290.0     290.0     290.00000     290.0       0
# 1980-03-21 00:00:00-05:00     290.0     290.0     290.00000     290.0       0
# ...                             ...       ...           ...       ...     ...
# 2023-05-17 00:00:00-04:00  498176.0  503000.0  494787.00000  500600.0    6000
# 2023-05-18 00:00:00-04:00  502450.0  505420.0  498125.00000  504360.0    5900
# 2023-05-19 00:00:00-04:00  505890.0  511335.0  503905.00000  507161.0    6400
# 2023-05-22 00:00:00-04:00  506673.0  509654.0  500697.00000  501148.0    9700
# 2023-05-23 00:00:00-04:00  499999.0  502200.0  496871.03125  497500.0    4727
#
# ...

# %%
df = pd.DataFrame().ta.ticker("pltr", period="1y", interval="1h")

# %%
df.ta.strategy(ta.CommonStrategy)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df.ta.strategy(ta.CommonStrategy)
#
# File ~/dev/market-probe/venv/lib/python3.11/site-packages/pandas_ta/core.py:725, in AnalysisIndicators.strategy(self, *args, **kwargs)
#     723 if use_multiprocessing:
#     724     _total_ta = len(ta)
# --> 725     with Pool(self.cores) as pool:
#     726         # Some magic to optimize chunksize for speed based on total ta indicators
#     727         _chunksize = mp_chunksize - 1 if mp_chunksize > _total_ta else int(npLog10(_total_ta)) + 1
#     728         if verbose:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/context.py:119, in BaseContext.Pool(self, processes, initializer, initargs, maxtasksperchild)
#     117 '''Returns a process pool object'''
#     118 from .pool import Pool
# ...

# %%
df.ta.categories
# Out:
# ['candles',
#  'cycles',
#  'momentum',
#  'overlap',
#  'performance',
#  'statistics',
#  'trend',
#  'volatility',
#  'volume']

# %%
df
# Out:
#                               Open   High     Low   Close    Volume  \
# Datetime
# 2022-05-23 11:30:00-04:00   7.9999   8.13   7.985   8.100         0
# 2022-05-23 12:30:00-04:00   8.1000   8.10   7.925   7.980   2646719
# 2022-05-23 13:30:00-04:00   7.9883   8.02   7.950   7.990   2457439
# 2022-05-23 14:30:00-04:00   7.9950   8.04   7.960   7.975   2679106
# 2022-05-23 15:30:00-04:00   7.9750   8.02   7.950   8.010   3197901
# ...                            ...    ...     ...     ...       ...
# 2023-05-22 14:30:00-04:00  11.9150  11.96  11.810  11.895   5887896
# 2023-05-22 15:30:00-04:00  11.8900  11.91  11.820  11.830   5375353
# 2023-05-23 09:30:00-04:00  11.9500  13.01  11.870  12.875  49241069
# 2023-05-23 10:30:00-04:00  12.8750  13.42  12.850  13.040  33529374
# 2023-05-23 11:30:00-04:00  13.0387  13.31  13.000  13.065  15367169
#
#                            Dividends  Stock Splits
# Datetime
# 2022-05-23 11:30:00-04:00        0.0           0.0
# ...

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.100764    0.101203    0.100764    0.100764
# 1980-12-15 00:00:00-05:00    0.095946    0.095946    0.095508    0.095508
# 1980-12-16 00:00:00-05:00    0.088936    0.088936    0.088498    0.088498
# 1980-12-17 00:00:00-05:00    0.090688    0.091126    0.090688    0.090688
# 1980-12-18 00:00:00-05:00    0.093317    0.093755    0.093317    0.093317
# ...                               ...         ...         ...         ...
# 2023-05-17 00:00:00-04:00  171.710007  172.929993  170.419998  172.690002
# 2023-05-18 00:00:00-04:00  173.000000  175.240005  172.580002  175.050003
# 2023-05-19 00:00:00-04:00  176.389999  176.389999  174.940002  175.160004
# 2023-05-22 00:00:00-04:00  173.979996  174.710007  173.449997  174.199997
# 2023-05-23 00:00:00-04:00  173.130005  173.379395  172.315002  172.315002
#
# ...

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.100764    0.101203    0.100764    0.100764
# 1980-12-15 00:00:00-05:00    0.095946    0.095946    0.095508    0.095508
# 1980-12-16 00:00:00-05:00    0.088936    0.088936    0.088498    0.088498
# 1980-12-17 00:00:00-05:00    0.090688    0.091126    0.090688    0.090688
# 1980-12-18 00:00:00-05:00    0.093317    0.093755    0.093317    0.093317
# ...                               ...         ...         ...         ...
# 2023-05-17 00:00:00-04:00  171.710007  172.929993  170.419998  172.690002
# 2023-05-18 00:00:00-04:00  173.000000  175.240005  172.580002  175.050003
# 2023-05-19 00:00:00-04:00  176.389999  176.389999  174.940002  175.160004
# 2023-05-22 00:00:00-04:00  173.979996  174.710007  173.449997  174.199997
# 2023-05-23 00:00:00-04:00  173.130005  173.379395  172.125000  172.169998
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
df.ta.strategy("Momentum")
# Out:
# 39it [00:02, 18.94it/s]

# %%
# filter by after jan 1 2021
df = df[df.index > "2021-01-01"]

# %%
for (key, value) in df.iloc[0].items():
    print(key, value)
# Out:
# Open 133.0947120378984
# High 133.18442171654382
# Low 126.35624207903588
# Close 128.997802734375
# Volume 143301900.0
# Dividends 0.0
# Stock Splits 0.0
# AO_5_34 9.79692827532081
# APO_12_26 4.906436626727768
# BIAS_SMA_26 0.02535149189693997
# BOP -0.6000002227560958
# AR_26 98.27969562302849
# BR_26 154.69822902538064
# CCI_14_0.015 -7.198798329450561
# CFO_9 -3.01126987882133
# CG_10 -5.469014780079352
# CMO_14 9.915290026047668
# COPC_11_14_10 14.293414333898555
# CTI_12 0.6225886854185375
# ER_10 0.03350687684526936
# BULLP_13 3.217617876156794
# BEARP_13 -3.61056176135115
# FISHERT_9_1 1.4933058193980524
# FISHERTs_9_1 2.1537459267039814
# INERTIA_20_14 47.02402268439338
# K_9_3 60.36348192686979
# D_9_3 71.25270237935233
# J_9_3 38.585041021904715
# KST_10_15_20_30_10_10_10_15 10220.647302662353
# KSTs_9 9197.212280756847
# MACD_12_26_9 3.4513753561055864
# MACDh_12_26_9 0.04057900537033632
# MACDs_12_26_9 3.41079635073525
# MOM_10 0.7077484130859375
# ...
